# %%
# pandas
import pandas as pd

tabela = pd.read_excel("DadosCarros.xlsx")

# %%
marca = list(tabela['MARCA'])
print(set(marca))
for carro in set(marca):
    print(carro)
# Out:
# {'Volkswagen', 'Ford', 'Caoa Chery', 'Hyundai', 'Audi', 'Kia', 'Porsche', 'Land Rover', 'Honda', 'Mitsubishi', 'Fiat', 'Toyota', 'Mercedes-Benz', 'Citroen', 'Volvo', 'Chevrolet', 'Nissan', 'Jeep', 'Peugeot', 'Renault'}
# Volkswagen
# Ford
# Caoa Chery
# Hyundai
# Audi
# Kia
# Porsche
# Land Rover
# Honda
# Mitsubishi
# Fiat
# Toyota
# Mercedes-Benz
# Citroen
# Volvo
# Chevrolet
# Nissan
# Jeep
# Peugeot
# Renault

# %%
modelo = list(tabela['MODELO'])
for carro in modelo:
    print(carro)
# Out:
# TIGGO 5X
# TIGGO 7
# TIGGO 8
# ARRIZO 6
# TIGGO 3X
# ARRIZO 6 PRO
# ARRIZO 6 PRO HYBRID
# HB20
# HB20S
# CRETA
# TUCSON
# IX35
# AZERA
# GOL
# GOLF
# VOYAGE
# POLO
# VIRTUS
# NIVUS
# T-CROSS
# JETTA
# SAVEIRO
# AMAROK
# ONIX
# ONIX PLUS
# CRUZE
# SPIN
# TRACKER
# S10
# CAMARO
# PULSE
# TOTO
# STRADA
# CRONOS
# MOBI
# ARGO
# FIORINO
# 500
# KWID
# SANDERO
# STEPWAY
# LOGAN
# CAPTUR
# DUSTER
# OROCH
# CLASSE A HATCH
# EQS SEDAN
# CLASSE A SEDAN
# CLASSE C SEDAN
# GLA SUV
# GLC COUPÉ
# RANGE ROVER
# RANGE ROVER SPORT
# RANGE ROVER VELAR
# RANGE ROVER EVOQUE
# DISCOVERY
# DISCOVERY SPORT
# RANGER
# TERRITORY
# BRONCO SPORT
# MAVERICK
# COROLLA CROSS
# COROLLA
# YARIS HATCH
# YARIS SEDÃ
# HILUX
# SW4
# RAV4
# SPORTAGE
# SORENTO
# CERATO
# E-TRON
# A3
# A4
# A5
# Q3
# Q5
# Q7
# Q8
# RENEGADE
# COMPASS
# COMMANDER
# GRAND CHEROKEE
# HR-V
# CITY HATCHBACK
# CITY
# CIVIC
# CR-V
# 208
# E-208
# 2008
# 3008
# FRONTIER
# KICKS
# VERSA
# LEAF
# PAJERO SPORT
# OUTLANDER
# ECLIPSE CROSS
# ...

# %%
classe_df = list(tabela['CLASSE'])

# %%
nomes = pd.read_csv("NationalNames.csv", sep=';')
display(nomes)
# Out:
#               Id       Name  Year Gender  Count          Last Name
# 0              1       Mary  1880      F   7065       913465 smith
# 1              2       Anna  1880      F   2604     571819 johnson
# 2              3       Emma  1880      F   2003       512312 jones
# 3              4  Elizabeth  1880      F   1939    503266 williams
# 4              5     Minnie  1880      F   1746       471390 brown
# ...          ...        ...   ...    ...    ...                ...
# 1048570  1048571   Erendira  1989      F     38           5 negrei
# 1048571  1048572       Gema  1989      F     38         5 negrazis
# 1048572  1048573        Ina  1989      F     38          5 negrave
# 1048573  1048574    Jacelyn  1989      F     38           5 negran
# 1048574  1048575      Jacki  1989      F     38        5 negonsott
#
# [1048575 rows x 6 columns]

# %%
fname_df = list(nomes['Name'])
fnames = set(fname_df)
print(fnames)
# Out:
# {'Cosette', 'Lacheryl', 'Shenda', 'Rosemary', 'Vishal', 'Murry', 'Deyanna', 'Shametrice', 'Lashonna', 'Francys', 'Miami', 'Shareika', 'Abie', 'Taquana', 'Jaleesia', 'Shetia', 'Suean', 'Mitzi', 'Kalab', 'Lueller', 'Basiliki', 'Maryn', 'Kipling', 'Gula', 'Jeweline', 'Phylisa', 'Philipp', 'Robt', 'Chizue', 'Wandalee', 'Thurmon', 'Darrol', 'Rebcca', 'Vaneesa', 'Rebekha', 'Deonn', 'Geannie', 'Mercedita', 'Exer', 'Karinda', 'Dasia', 'Archie', 'Crispina', 'Rachell', 'Quartterio', 'Fabiana', 'Nayo', 'Winslow', 'Martain', 'Derion', 'Salar', 'Shataka', 'Beverlie', 'Shakelia', 'Jehnna', 'Jalesia', 'Sopheap', 'Toan', 'Zoraya', 'Sheneice', 'Neddie', 'Thadd', 'Soula', 'Lazzaro', 'Jolisa', 'Deanglo', 'Latese', 'Treveon', 'Marhta', 'Machael', 'Gennine', 'Ferol', 'Shamaine', 'Erline', 'Atonya', 'Gustavia', 'Coella', 'Krzysztof', 'Uleta', 'Noren', 'Monick', 'Charlet', 'Kwana', 'Jermond', 'Tajana', 'Aniceto', 'Ballarie', 'Sandralee', 'Tyria', 'Cesia', 'Laquietta', 'Chimera', 'Sujatha', 'Marelin', 'Elow
# ...

# %%
# lname = list(nomes['Last Name'])
# lname.sort(reverse=True)
# print(lname[:10])
# for i in range(10):
#     lname[i] = lname[i].strip()
#     ln = lname[i].split(' ')
#     print(ln)
    
# # lnames = set(lname_df)
# # print(lname_df)
# # print(len(lname_df))
# # print(len(lnames))

# %%
lname = list(nomes['Last Name'])
# print(lname[:100])
#print(len(lname))
name_list = []
for name in lname[:100000]:
    name = name.strip()
    nm = name.split(' ')
    if len(nm) == 2:
        nome = nm[1].capitalize()
        name_list.append(nome)
#     elif len(nm) == 1:
#         nome = nm[1] #.capitalize()
#         name_list.append(nome)

print(name_list)
print(len(set(name_list)))
# lnames = set(lname_df)
# print(lname_df)
# print(len(lname_df))
# print(len(lnames))
# Out:
# ['Smith', 'Johnson', 'Jones', 'Williams', 'Brown', 'Lee', 'Khan', 'Singh', 'Kumar', 'Miller', 'Davis', 'Wilson', 'Taylor', 'Thomas', 'Garcia', 'Anderson', 'Sharma', 'Martin', 'Rodriguez', 'Ali', 'White', 'Jackson', 'Thompson', 'Moore', 'Ahmed', 'Martinez', 'Lopez', 'Harris', 'Patel', 'King', 'Walker', 'Hernandez', 'Clark', 'Lewis', 'Robinson', 'Young', 'Gonzalez', 'Hall', 'Wright', 'Scott', 'Perez', 'Green', 'Allen', 'Tan', 'Shah', 'Roberts', 'Adams', 'Nguyen', 'James', 'Hill', 'Baker', 'Campbell', 'Wong', 'Sanchez', 'Evans', 'Cruz', 'Gupta', 'Chan', 'Mitchell', 'Carter', 'Reyes', 'Nelson', 'Edwards', 'Rivera', 'Parker', 'Turner', 'Phillips', 'Lim', 'Murphy', 'Stewart', 'Collins', 'Jain', 'Torres', 'Morris', 'Santos', 'Kelly', 'Morgan', 'Cooper', 'Ramirez', 'Flores', 'Bell', 'Cook', 'Wood', 'Rogers', 'Ramos', 'Watson', 'Ward', 'Diaz', 'Bailey', 'Rose', 'Ahmad', 'Hughes', 'Bennett', 'Love', 'Kim', 'Mohamed', 'Gomez', 'Mendoza', 'Gray', 'Richardson', 'Ross', 'Cox', 'Chen', 'Reed', 'Bro
# ...

# %%
# pandas
import pandas as pd

tabela = pd.read_csv("registered_companies.csv", sep=',', low_memory=False)

# %%
companies = list(tabela['COMPANY_NAME'])

print(companies[0:3000])
# Out:
# ['NIKO RESOURCES LIMITED   ', 'WORLDWIDE RESOURCES HOLDINGS LTD   ', 'ATWOOD OCEANIC PACIFIC LIMITED   ', 'SOLVAY S A BELGIUM   ', 'TATE AND LYLE INDUSTRIES LTD   ', 'OVERSEAS TRADING AND SHIPPING CO LTD   ', 'BALLAST NADAM INTERNATIONAL B V   ', 'OIL AND GAS EXPLORATION COMPANY CRACOW LTD  ', 'PRECISION DRILLING CYPRUS LIMITED   ', 'GNRL OIL & GAS LIMITED   ', 'OIL AND GAS DRILLING COMPANY NAFTA LIMITED  ', 'MAJUKA ENTERPRISES PTE LIMITED   ', 'JSC NIJHPHARM   ', 'DALMA ENERGY LLC   ', 'ASENCE INC   ', 'DURAVIT A G   ', 'QUAD TECH INC   ', 'OILEX LTD   ', 'NORDSON XALOY ASIA (THAILAND) LIMITED   ', 'NUOVO PIGNONE S.P.A.   ', 'XEO SOFTWARE LLC   ', 'THEATRE SOLUTIONS INC   ', 'OILEX NL HOLDINGS (INDIA) LIMITED   ', 'KST INTERNATIONAL LTD   ', 'JOINT STOCK COMPANY ZANGAS   ', 'GRADA TEXTILE GMBH   ', 'CELTIC CROSS HOLDING INC.   ', 'SHANDONG TIEJUN ELECTRIC POWER ENGINEERING CO. LTD  ', 'HYPLAS MACHINERY CO. LIMITED   ', 'PRIMETALS TECHNOLOGIES FRANCE SAS   ', 'POROCEL INDUSTRIES LLC 
# ...
